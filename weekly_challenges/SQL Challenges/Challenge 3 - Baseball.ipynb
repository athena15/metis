# %% [markdown]
# # SQL in Pandas with SQLAlchemy
#
# We will use the "sshtunnel" library to connect to our remote AWS instance and then pull some data into Pandas using SQLAlchemy and Pyscopg2.

# %% [markdown]
# ## Creating the SSH Tunnel
#
# The "sshtunnel" library can read an SSH config file, so creating a tunnel is quite easy assuming SSH keys are setup and the SSH config entry has been created. With this setup, the "sshtunnel" library automatically determines what the address of the local port should be.

# %%
import pandas as pd
import os

# %%
pd.set_option('max_rows', 10)

# %%
# %load_ext dotenv
# %dotenv

# %load_ext autoreload
# %autoreload 2
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sshtunnel import SSHTunnelForwarder

AWS_IP_ADDRESS = '54.185.35.146'
AWS_USERNAME = os.environ.get('AWS_USERNAME')
SSH_KEY_PATH = '/Users/brenner/.ssh/id_rsa'

server = SSHTunnelForwarder(
    AWS_IP_ADDRESS,
    ssh_username=AWS_USERNAME,
    ssh_pkey=SSH_KEY_PATH,
    remote_bind_address=('localhost', 5432),
)

server.start()
print(server.is_active, server.is_alive, server.local_bind_port)
# Out:
# True True 53390

# %%
pd.set_option('max_columns', None)

# %% [markdown]
# ##  Connecting via Python
# We'll be using a Psycopg2 connector alongside SQLAlchemy to connect to this database.
#
# * **SQLAlchemy:** generates SQL statements
# * **Psycopg2:** sends the SQL statements to the Postgres database
#
#     Let's make the connection to the database. Note that the IP address of the Postgres database is 'localhost' and the port is set to whatever the `server` connection above contains. This is because we have used the SSH tunnel to create a connection between the AWS instance and our computer. SSH tunnels enable remote instances to behave as if they are *local*.

# %%
from sqlalchemy import create_engine

# Postgres username, password, and database name
POSTGRES_IP_ADDRESS = 'localhost' ## This is localhost because SSH tunnel is active
POSTGRES_PORT = str(server.local_bind_port)
POSTGRES_USERNAME = os.environ.get('POSTGRES_USERNAME')     ## CHANGE THIS TO YOUR POSTGRES USERNAME
POSTGRES_PASSWORD = os.environ.get('POSTGRES_PASSWORD') ## CHANGE THIS TO YOUR POSTGRES PASSWORD
POSTGRES_DBNAME = 'baseball'

# A long string that contains the necessary Postgres login information
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
                .format(username=POSTGRES_USERNAME, 
                        password=POSTGRES_PASSWORD,
                        ipaddress=POSTGRES_IP_ADDRESS,
                        port=POSTGRES_PORT,
                        dbname=POSTGRES_DBNAME))

# Create the connection
cnx = create_engine(postgres_str)

# %% [markdown]
# ## Load Some Data!
#
# Pandas has a `read_sql_query` method that will pass a SQL statement to a database connection. Here is an example from the all-star table.

# %%
import pandas as pd

pd.read_sql_query('''SELECT * FROM allstarfull LIMIT 5;''', cnx)
# Out:
#     playerid  yearid gamenum        gameid teamid lgid gp startingpos
# 0  gomezle01    1933       0  ALS193307060    NYA   AL  1           1
# 1  ferreri01    1933       0  ALS193307060    BOS   AL  1           2
# 2  gehrilo01    1933       0  ALS193307060    NYA   AL  1           3
# 3  gehrich01    1933       0  ALS193307060    DET   AL  1           4
# 4  dykesji01    1933       0  ALS193307060    CHA   AL  1           5

# %% [markdown]
# And another from the schools table.

# %%
pd.read_sql_query('''SELECT * FROM schools LIMIT 5;''', cnx)
# Out:
#      schoolid                       schoolname        schoolcity schoolstate  \
# 0  abilchrist     Abilene Christian University           Abilene          TX
# 1     adelphi               Adelphi University       Garden City          NY
# 2    adrianmi                   Adrian College            Adrian          MI
# 3    airforce  United States Air Force Academy  Colorado Springs          CO
# 4       akron              University of Akron             Akron          OH
#
#   schoolnick
# 0   Wildcats
# 1   Panthers
# 2   Bulldogs
# 3    Falcons
# 4       Zips

# %% [markdown]
# More sophisticated queries can also be used. This example finds the states with the most schools.

# %%
sql_query = '''SELECT schoolstate as state, Count(schoolid) as ct 
               FROM schools 
               GROUP BY state 
               ORDER BY ct DESC 
               LIMIT 5;'''

pd.read_sql_query(sql_query, cnx)
# Out:
#   state  ct
# 0    PA  57
# 1    CA  48
# 2    NY  45
# 3    TX  41
# 4    OH  33

# %% [markdown]
# Finally, this example finds five players from the year 1985 whose salary was above $500,000.

# %%
sql_query = '''SELECT playerid, salary 
               FROM Salaries 
               WHERE yearid = '1985' AND salary > '500000'
               ORDER BY salary DESC
               LIMIT 5;'''

pd.read_sql_query(sql_query, cnx)
# Out:
#     playerid     salary
# 0  schmimi01  2130300.0
# 1  cartega01  2028571.0
# 2  fostege01  1942857.0
# 3  winfida01  1795704.0
# 4  gossari01  1713333.0

# %% [markdown]
# ## Close Server Connection
#
# Finally, we should close the server connection when complete.

# %%
server.close()

# %% [markdown]
# 1. What was the total spent on salaries by each team, each year?

# %%
pd.read_sql_query('''
SELECT teamid, sum(salary) as sum
FROM Salaries
GROUP BY teamid''',
                 cnx)
# Out:
#    teamid           sum
# 0     ML4  2.336458e+08
# 1     NYA  3.085575e+09
# 2     PIT  9.173692e+08
# 3     BOS  2.293681e+09
# 4     TEX  1.557835e+09
# 5     HOU  1.372977e+09
# 6     LAN  2.020752e+09
# 7     CAL  2.719789e+08
# 8     COL  1.198507e+09
# 9     SEA  1.580612e+09
# 10    MIA  1.516799e+08
# 11    TBA  6.954218e+08
# 12    CHA  1.618035e+09
# 13    MIL  9.469441e+08
# 14    ANA  4.680920e+08
# 15    KCA  1.102873e+09
# 16    WAS  5.833763e+08
# 17    CLE  1.322864e+09
# 18    CHN  1.794311e+09
# 19    PHI  1.801411e+09
# 20    LAA  1.062683e+09
# 21    CIN  1.326558e+09
# 22    MON  4.082038e+08
# 23    BAL  1.526784e+09
# 24    DET  1.618342e+09
# 25    MIN  1.186475e+09
# 26    ARI  1.112114e+09
# 27    OAK  1.114146e+09
# 28    SLN  1.654938e+09
# 29    SFN  1.676243e+09
# 30    FLO  6.750160e+08
# 31    ATL  1.785338e+09
# 32    TOR  1.460955e+09
# 33    NYN  1.934987e+09
# 34    SDN  1.101814e+09

# %% [markdown]
# 2. What is the first and last year played for each player? *Hint:* Create a new table from 'Fielding.csv'.

# %%
pd.read_sql_query('''
SELECT *
FROM Fielding
''',
                 cnx)
# Out:
#          playerid  yearid  stint teamid lgid pos    g     gs  innouts     po  \
# 0       ansonca01    1871      1    RC1   NA  1B    1    NaN      NaN    7.0
# 1       biermch01    1871      1    FW1   NA  1B    1    NaN      NaN    9.0
# 2       carleji01    1871      1    CL1   NA  1B   29    NaN      NaN  295.0
# 3       connone01    1871      1    TRO   NA  1B    4    NaN      NaN   35.0
# 4       cravebi01    1871      1    TRO   NA  1B    2    NaN      NaN   18.0
# 5       fishech01    1871      1    RC1   NA  1B    2    NaN      NaN   12.0
# 6       fislewe01    1871      1    PH1   NA  1B   26    NaN      NaN  240.0
# 7       flynncl01    1871      1    TRO   NA  1B   19    NaN      NaN  183.0
# 8       foranji01    1871      1    FW1   NA  1B   16    NaN      NaN  111.0
# 9       fulmech01    1871      1    RC1   NA  1B    1    NaN      NaN    9.0
# 10      gouldch01    1871      1    BS1   NA  1B   30    NaN      NaN  343.0
# 11      hastisc01    1871      1    RC1   NA  1B    1    NaN      NaN    4.0
# 12      heubege01    1871      1    PH1   NA  1B    1    NaN      NaN    6.0
# 13      kohlehe01    1871      1    FW1   NA  1B    2    NaN      NaN   17.0
# 14       mackde01    1871      1    RC1   NA  1B   24    NaN      NaN  271.0
# 15      mcatebu01    1871      1    CH1   NA  1B   26    NaN      NaN  276.0
# 16      millsev01    1871      1    WS3   NA  1B   32    NaN      NaN  343.0
# 17      phelpne01    1871      1    FW1   NA  1B    1    NaN      NaN    8.0
# 18       pikeli01    1871      1    TRO   NA  1B    4    NaN      NaN   44.0
# 19      prattto01    1871      1    PH1   NA  1B    1    NaN      NaN   11.0
# 20      simmojo01    1871      1    CH1   NA  1B    2    NaN      NaN   18.0
# 21      startjo01    1871      1    NY2   NA  1B   33    NaN      NaN  334.0
# 22      wrighge01    1871      1    BS1   NA  1B    1    NaN      NaN    9.0
# 23       addybo01    1871      1    RC1   NA  2B   22    NaN      NaN   67.0
# 24      allisar01    1871      1    CL1   NA  2B    2    NaN      NaN    1.0
# 25      ansonca01    1871      1    RC1   NA  2B    2    NaN      NaN    3.0
# 26      barnero01    1871      1    BS1   NA  2B   16    NaN      NaN   42.0
# 27      barrofr01    1871      1    BS1   NA  2B    1    NaN      NaN    2.0
# 28      bealsto01    1871      1    WS3   NA  2B    2    NaN      NaN    9.0
# 29      beaveed01    1871      1    TRO   NA  2B    3    NaN      NaN    8.0
# ...           ...     ...    ...    ...  ...  ..  ...    ...      ...    ...
# 166961  ramirjo01    2013      1    CLE   AL  SS    2    0.0      6.0    0.0
# 166962  ransoco01    2013      1    CHN   NL  SS    1    1.0     24.0    1.0
# 166963  rendoan01    2013      1    WAS   NL  SS    4    2.0     83.0    9.0
# 166964  reyesjo01    2013      1    TOR   AL  SS   92   92.0   2379.0   95.0
# 166965  rodrise01    2013      1    TBA   AL  SS    7    3.0     84.0    3.0
# 166966  rolliji01    2013      1    PHI   NL  SS  153  151.0   3955.0  190.0
# 166967  rominan01    2013      1    LAA   AL  SS   17    6.0    260.0   18.0
# 166968  rosalad01    2013      1    OAK   AL  SS   36   33.0    861.0   46.0
# 166969  rosalad01    2013      2    TEX   AL  SS    3    0.0     18.0    0.0
# 166970  rutlejo01    2013      1    COL   NL  SS   14   13.0    346.0   23.0
# 166971   ryanbr01    2013      1    SEA   AL  SS   84   79.0   2106.0   96.0
# 166972   ryanbr01    2013      2    NYA   AL  SS   17   17.0    456.0   15.0
# 166973  santira01    2013      1    DET   AL  SS   27   19.0    578.0   20.0
# 166974  segurje01    2013      1    MIL   NL  SS  144  143.0   3753.0  199.0
# 166975  selleju01    2013      1    LAN   NL  SS   22   20.0    532.0   22.0
# 166976  semiema01    2013      1    CHA   AL  SS    3    3.0     82.0    7.0
# 166977  simmoan01    2013      1    ATL   NL  SS  156  150.0   4057.0  240.0
# 166978  sogarer01    2013      1    OAK   AL  SS   15   12.0    338.0   27.0
# 166979  tejadru01    2013      1    NYN   NL  SS   55   55.0   1497.0   72.0
# 166980  tovarwi01    2013      1    NYN   NL  SS    7    5.0    139.0    5.0
# 166981  triunca01    2013      1    SEA   AL  SS   10    8.0    216.0   11.0
# 166982  tulowtr01    2013      1    COL   NL  SS  121  119.0   3088.0  183.0
# 166983  turneju01    2013      1    NYN   NL  SS   18   13.0    346.0   19.0
# 166984  valaich01    2013      1    MIA   NL  SS    6    6.0    159.0    5.0
# 166985  valdejo02    2013      1    NYN   NL  SS    1    0.0      6.0    0.0
# 166986  villajo01    2013      1    HOU   AL  SS   58   57.0   1497.0   95.0
# 166987  walteza01    2013      1    WAS   NL  SS    2    1.0     30.0    0.0
# 166988  wilsojo03    2013      1    ARI   NL  SS    2    0.0      9.0    0.0
# 166989  youngmi02    2013      1    LAN   NL  SS    1    1.0     21.0    0.0
# 166990  zobribe01    2013      1    TBA   AL  SS   21   11.0    345.0   11.0
#
#             a     e    dp  pb  wp  sb  cs  zr
# 0         0.0   0.0   0.0 NaN NaN NaN NaN NaN
# 1         0.0   2.0   0.0 NaN NaN NaN NaN NaN
# 2         4.0  34.0  10.0 NaN NaN NaN NaN NaN
# 3         1.0   5.0   1.0 NaN NaN NaN NaN NaN
# 4         1.0   1.0   1.0 NaN NaN NaN NaN NaN
# 5         0.0   1.0   0.0 NaN NaN NaN NaN NaN
# 6         1.0   7.0   9.0 NaN NaN NaN NaN NaN
# 7         8.0   9.0  12.0 NaN NaN NaN NaN NaN
# 8         4.0  16.0   2.0 NaN NaN NaN NaN NaN
# 9         0.0   0.0   0.0 NaN NaN NaN NaN NaN
# 10        3.0  36.0  21.0 NaN NaN NaN NaN NaN
# 11        0.0   1.0   0.0 NaN NaN NaN NaN NaN
# 12        0.0   0.0   0.0 NaN NaN NaN NaN NaN
# 13        0.0   1.0   0.0 NaN NaN NaN NaN NaN
# 14        6.0  19.0  11.0 NaN NaN NaN NaN NaN
# 15        5.0  17.0  14.0 NaN NaN NaN NaN NaN
# 16        5.0  12.0  16.0 NaN NaN NaN NaN NaN
# 17        0.0   1.0   1.0 NaN NaN NaN NaN NaN
# 18        0.0   5.0   3.0 NaN NaN NaN NaN NaN
# 19        0.0   3.0   0.0 NaN NaN NaN NaN NaN
# 20        0.0   2.0   0.0 NaN NaN NaN NaN NaN
# 21        2.0  29.0  11.0 NaN NaN NaN NaN NaN
# 22        1.0   0.0   1.0 NaN NaN NaN NaN NaN
# 23       72.0  42.0   5.0 NaN NaN NaN NaN NaN
# 24        4.0   0.0   0.0 NaN NaN NaN NaN NaN
# 25        4.0   1.0   0.0 NaN NaN NaN NaN NaN
# 26       61.0  15.0  10.0 NaN NaN NaN NaN NaN
# 27        0.0   1.0   0.0 NaN NaN NaN NaN NaN
# 28        7.0   0.0   1.0 NaN NaN NaN NaN NaN
# 29       10.0   4.0   2.0 NaN NaN NaN NaN NaN
# ...       ...   ...   ...  ..  ..  ..  ..  ..
# 166961    0.0   0.0   0.0 NaN NaN NaN NaN NaN
# 166962    3.0   0.0   0.0 NaN NaN NaN NaN NaN
# 166963    2.0   2.0   1.0 NaN NaN NaN NaN NaN
# 166964  240.0   9.0  51.0 NaN NaN NaN NaN NaN
# 166965    8.0   1.0   1.0 NaN NaN NaN NaN NaN
# 166966  424.0  11.0  89.0 NaN NaN NaN NaN NaN
# 166967   29.0   1.0   8.0 NaN NaN NaN NaN NaN
# 166968   99.0   7.0  13.0 NaN NaN NaN NaN NaN
# 166969    2.0   0.0   1.0 NaN NaN NaN NaN NaN
# 166970   37.0   1.0   8.0 NaN NaN NaN NaN NaN
# 166971  240.0  11.0  52.0 NaN NaN NaN NaN NaN
# 166972   61.0   1.0  12.0 NaN NaN NaN NaN NaN
# 166973   49.0   2.0   7.0 NaN NaN NaN NaN NaN
# 166974  459.0  15.0  96.0 NaN NaN NaN NaN NaN
# 166975   48.0   3.0  11.0 NaN NaN NaN NaN NaN
# 166976   13.0   0.0   0.0 NaN NaN NaN NaN NaN
# 166977  499.0  14.0  94.0 NaN NaN NaN NaN NaN
# 166978   28.0   2.0   2.0 NaN NaN NaN NaN NaN
# 166979  177.0   8.0  37.0 NaN NaN NaN NaN NaN
# 166980   15.0   0.0   4.0 NaN NaN NaN NaN NaN
# 166981   23.0   2.0   6.0 NaN NaN NaN NaN NaN
# 166982  379.0   8.0  84.0 NaN NaN NaN NaN NaN
# 166983   32.0   0.0   8.0 NaN NaN NaN NaN NaN
# 166984   13.0   1.0   3.0 NaN NaN NaN NaN NaN
# 166985    0.0   0.0   0.0 NaN NaN NaN NaN NaN
# 166986  141.0  16.0  38.0 NaN NaN NaN NaN NaN
# 166987    6.0   0.0   1.0 NaN NaN NaN NaN NaN
# 166988    2.0   1.0   0.0 NaN NaN NaN NaN NaN
# 166989    2.0   0.0   0.0 NaN NaN NaN NaN NaN
# 166990   37.0   1.0   5.0 NaN NaN NaN NaN NaN
#
# [166991 rows x 18 columns]

# %% [markdown]
# 3. Who has played the most all star games?

# %%
pd.read_sql_query('''
SELECT playerid, Count(yearid) as cnt
FROM allstarfull
GROUP BY playerid
ORDER BY cnt DESC
''',
                 cnx)
# Out:
#        playerid  cnt
# 0     aaronha01   25
# 1     musiast01   24
# 2      mayswi01   24
# 3     mantlmi01   20
# 4     willite01   19
# 5     ripkeca01   19
# 6     carewro01   18
# 7     yastrca01   18
# 8     kalinal01   18
# 9     robinbr01   18
# 10    berrayo01   18
# 11    spahnwa01   17
# 12     rosepe01   17
# 13      foxne01   15
# 14    gwynnto01   15
# 15    clemero01   15
# 16    smithoz01   15
# 17    jacksre01   14
# 18    bankser01   14
# 19    rodriiv01   14
# 20    benchjo01   14
# 21    robinfr02   14
# 22    bondsba01   14
# 23    rodrial01   14
# 24    riverma01   13
# 25    jeterde01   13
# 26    dimagjo01   13
# 27    griffke02   13
# 28    brettge01   13
# 29    aparilu01   13
# ...         ...  ...
# 1646  mcgloly01    1
# 1647  davisro02    1
# 1648  younger01    1
# 1649  sewellu01    1
# 1650  westlwa01    1
# 1651  heywaja01    1
# 1652  dobsojo01    1
# 1653   wertdo01    1
# 1654  bibbyji01    1
# 1655  carpema01    1
# 1656  francti01    1
# 1657   rijojo01    1
# 1658  hansoer01    1
# 1659  travebi01    1
# 1660   bereja01    1
# 1661  fletcda01    1
# 1662  sanchga01    1
# 1663  muncrbo01    1
# 1664  drabedo01    1
# 1665  rhodear01    1
# 1666   yosted01    1
# 1667  bakerge02    1
# 1668  joynewa01    1
# 1669  manushe01    1
# 1670  gromest01    1
# 1671  grababi01    1
# 1672  colemjo04    1
# 1673  bonesri01    1
# 1674  lankfra01    1
# 1675  lonboji01    1
#
# [1676 rows x 2 columns]

# %% [markdown]
# 4. Which school has generated the most distinct players? *Hint:* Create new table from 'SchoolsPlayers.csv'.

# %%
query = '''

pd.read_sql_query(query, cnx)

# %%
query = '''
CREATE TEMP TABLE temp_table
ON COMMIT DROP
AS
SELECT *
FROM schoolsplayers;

COPY temp_table FROM '/home/brenner/baseballdata/SchoolsPlayers.csv' DELIMITER ',' CSV HEADER;

INSERT INTO schoolsplayers
SELECT DISTINCT playerID
FROM temp_table
'''

pd.read_sql_query(query, cnx)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# IntegrityError: duplicate key value violates unique constraint "schoolsplayers_pkey"
# DETAIL:  Key (playerid)=(fritzla01) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-10-308f0dcff85c> in <module>()
#      13 '''
#      14
# ---> 15 pd.read_sql_query(query, cnx)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# -> 1063         result = self.execute(*args)
#    1064         columns = result.keys()
#    1065
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     952     def execute(self, *args, **kwargs):
#     953         """Simple passthrough to SQLAlchemy connectable"""
# --> 954         return self.connectable.execute(*args, **kwargs)
#     955
#     956     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "schoolsplayers_pkey"
# DETAIL:  Key (playerid)=(fritzla01) already exists.
#  [SQL: "\nCREATE TEMP TABLE temp_table\nON COMMIT DROP\nAS\nSELECT *\nFROM schoolsplayers;\n\nCOPY temp_table FROM '/home/brenner/baseballdata/SchoolsPlayers.csv' DELIMITER ',' CSV HEADER;\n\nINSERT INTO schoolsplayers\nSELECT DISTINCT playerID\nFROM temp_table\n"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
pd.read_sql_query('''
SELECT *
FROM
''', cnx)
# Out:
# Empty DataFrame
# Columns: [playerid, schoolid, yearmin, yearmax]
# Index: []

# %%
pd.read_sql_query('''
SELECT *
FROM allstarfull
''', cnx)
# Out:
#        playerid  yearid gamenum        gameid teamid lgid gp startingpos
# 0     gomezle01    1933       0  ALS193307060    NYA   AL  1           1
# 1     ferreri01    1933       0  ALS193307060    BOS   AL  1           2
# 2     gehrilo01    1933       0  ALS193307060    NYA   AL  1           3
# 3     gehrich01    1933       0  ALS193307060    DET   AL  1           4
# 4     dykesji01    1933       0  ALS193307060    CHA   AL  1           5
# ...         ...     ...     ...           ...    ...  ... ..         ...
# 4907  alvarpe01    2013       0  NLS201307160    PIT   NL  1        None
# 4908  corbipa01    2013       0  NLS201307160    ARI   NL  1        None
# 4909  goldspa01    2013       0  NLS201307160    ARI   NL  1        None
# 4910   romose01    2013       0  NLS201307160    SFN   NL  0        None
# 4911   woodtr01    2013       0  NLS201307160    CHN   NL  0        None
#
# [4912 rows x 8 columns]

# %% [markdown]
# 5. Which players have the longest career? Assume that the `debut` and `finalGame` columns comprise the start and end, respectively, of a player's career. *Hint:* Create a new table from 'Master.csv'. Also note that strings can be converted to dates using the [`DATE`](https://wiki.postgresql.org/wiki/Working_with_Dates_and_Times_in_PostgreSQL#WORKING_with_DATETIME.2C_DATE.2C_and_INTERVAL_VALUES) function and can then be subtracted from each other yielding their difference in days.

# %%
query = '''
SELECT *
FROM schoolsplayers
'''

pd.read_sql_query(query, cnx)
# Out:
# Empty DataFrame
# Columns: [playerid, schoolid, yearmin, yearmax]
# Index: []

# %%
query = '''
SELECT *
FROM Fielding
JOIN allstarfull ON fielding.playerid = allstarfull.playerid
'''

pd.read_sql_query(query, cnx)
# Out:
#          playerid  yearid  stint teamid lgid pos   g    gs  innouts    po  \
# 0         dyeje01    2003      1    OAK   AL  DH   3   NaN      NaN   NaN
# 1         dyeje01    2003      1    OAK   AL  DH   3   NaN      NaN   NaN
# 2       pinielo01    1974      1    NYA   AL  DH   6   NaN      NaN   NaN
# 3       pinsova01    1974      1    KCA   AL  DH   2   NaN      NaN   NaN
# 4       pinsova01    1974      1    KCA   AL  DH   2   NaN      NaN   NaN
# ...           ...     ...    ...    ...  ...  ..  ..   ...      ...   ...
# 136778  youngmi02    2013      1    LAN   NL  SS   1   1.0     21.0   0.0
# 136779  youngmi02    2013      1    LAN   NL  SS   1   1.0     21.0   0.0
# 136780  youngmi02    2013      1    LAN   NL  SS   1   1.0     21.0   0.0
# 136781  zobribe01    2013      1    TBA   AL  SS  21  11.0    345.0  11.0
# 136782  zobribe01    2013      1    TBA   AL  SS  21  11.0    345.0  11.0
#
#            a    e   dp  pb  wp  sb  cs  zr   playerid  yearid gamenum  \
# 0        NaN  NaN  NaN NaN NaN NaN NaN NaN    dyeje01    2006       0
# 1        NaN  NaN  NaN NaN NaN NaN NaN NaN    dyeje01    2000       0
# 2        NaN  NaN  NaN NaN NaN NaN NaN NaN  pinielo01    1972       0
# 3        NaN  NaN  NaN NaN NaN NaN NaN NaN  pinsova01    1960       2
# 4        NaN  NaN  NaN NaN NaN NaN NaN NaN  pinsova01    1960       1
# ...      ...  ...  ...  ..  ..  ..  ..  ..        ...     ...     ...
# 136778   2.0  0.0  0.0 NaN NaN NaN NaN NaN  youngmi02    2006       0
# 136779   2.0  0.0  0.0 NaN NaN NaN NaN NaN  youngmi02    2005       0
# 136780   2.0  0.0  0.0 NaN NaN NaN NaN NaN  youngmi02    2004       0
# 136781  37.0  1.0  5.0 NaN NaN NaN NaN NaN  zobribe01    2013       0
# 136782  37.0  1.0  5.0 NaN NaN NaN NaN NaN  zobribe01    2009       0
#
#               gameid teamid lgid gp startingpos
# 0       NLS200607110    CHA   AL  1        None
# 1       NLS200007110    KCA   AL  1           9
# 2       NLS197207250    KCA   AL  1        None
# 3       ALS196007130    CIN   NL  1        None
# 4       ALS196007110    CIN   NL  1        None
# ...              ...    ...  ... ..         ...
# 136778  NLS200607110    TEX   AL  1        None
# 136779  ALS200507120    TEX   AL  1        None
# 136780  NLS200407130    TEX   AL  1        None
# 136781  NLS201307160    TBA   AL  0        None
# 136782  NLS200907140    TBA   AL  1        None
#
# [136783 rows x 26 columns]

# %%
query = '''
SELECT *
FROM Fielding
JOIN allstarfull ON fielding.playerid = allstarfull.playerid
'''

pd.read_sql_query(query, cnx)

# %%
query = '''
CREATE TABLE IF NOT EXISTS Master (
    playerID varchar(20) NOT NULL,
    birthYear int DEFAULT NULL,
    birthMonth int DEFAULT NULL,
    birthDay int DEFAULT NULL,
    birthCountry text DEFAULT NULL,
    birthState text DEFAULT NULL,
    birthCity text DEFAULT NULL,
    deathYear int DEFAULT NULL,
    deathMonth int DEFAULT NULL,
    deathDay int DEFAULT NULL,
    deathCountry text DEFAULT NULL,
    deathState text DEFAULT NULL,
    deathCity text DEFAULT NULL,
    nameFirst text DEFAULT NULL,
    nameLast text DEFAULT NULL,
    nameGiven text DEFAULT NULL,
    weight int DEFAULT NULL,
    height int DEFAULT NULL,
    bats text DEFAULT NULL,
    throws text DEFAULT NULL,
    debut text DEFAULT NULL,
    finalGame text DEFAULT NULL,
    retroID varchar(20) DEFAULT NULL,
    bbrefID varchar(20) DEFAULT NULL,
    PRIMARY KEY (nameLast, nameFirst));

COPY Master FROM '/home/brenner/baseballdata/Master.csv' DELIMITER ',' CSV HEADER;
'''

pd.read_sql_query(query, cnx)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# IntegrityError: duplicate key value violates unique constraint "master_pkey"
# DETAIL:  Key (playerid)=(aardsda01) already exists.
# CONTEXT:  COPY master, line 2
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-14-418dff9f12f7> in <module>()
#      31 '''
#      32
# ---> 33 pd.read_sql_query(query, cnx)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# -> 1063         result = self.execute(*args)
#    1064         columns = result.keys()
#    1065
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     952     def execute(self, *args, **kwargs):
#     953         """Simple passthrough to SQLAlchemy connectable"""
# --> 954         return self.connectable.execute(*args, **kwargs)
#     955
#     956     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "master_pkey"
# DETAIL:  Key (playerid)=(aardsda01) already exists.
# CONTEXT:  COPY master, line 2
#  [SQL: "\n\nCREATE TABLE IF NOT EXISTS Master (\n    playerID varchar(20) NOT NULL,\n    birthYear int DEFAULT NULL,\n    birthMonth int DEFAULT NULL,\n    birthDay int DEFAULT NULL,\n    birthCountry text DEFAULT NULL,\n    birthState text DEFAULT NULL,\n    birthCity text DEFAULT NULL,\n    deathYear int DEFAULT NULL,\n    deathMonth int DEFAULT NULL,\n    deathDay int DEFAULT NULL,\n    deathCountry text DEFAULT NULL,\n    deathState text DEFAULT NULL,\n    deathCity text DEFAULT NULL,\n    nameFirst text DEFAULT NULL,\n    nameLast text DEFAULT NULL,\n    nameGiven text DEFAULT NULL,\n    weight int DEFAULT NULL,\n    height int DEFAULT NULL,\n    bats text DEFAULT NULL,\n    throws text DEFAULT NULL,\n    debut text DEFAULT NULL,\n    finalGame text DEFAULT NULL,\n    retroID varchar(20) DEFAULT NULL,\n    bbrefID varchar(20) DEFAULT NULL,\n    PRIMARY KEY (nameLast, nameFirst));\n\nCOPY Master FROM '/home/brenner/baseballdata/Master.csv' DELIMITER ',' CSV HEADER;\n"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
query = '''
SELECT *
FROM Master
'''

pd.read_sql_query(query, cnx)
# Out:
#         playerid  birthyear  birthmonth  birthday birthcountry birthstate  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 18349  zupcibo01     1966.0         8.0      18.0          USA         PA
# 18350   zupofr01     1939.0         8.0      29.0          USA         CA
# 18351  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 18352  zuverge01     1924.0         8.0      20.0          USA         MI
# 18353  zwilldu01     1888.0        11.0       2.0          USA         MO
#
#            birthcity  deathyear  deathmonth  deathday deathcountry deathstate  \
# 0             Denver        NaN         NaN       NaN         None       None
# 1             Mobile        NaN         NaN       NaN         None       None
# 2             Mobile     1984.0         8.0      16.0          USA         GA
# 3             Orange        NaN         NaN       NaN         None       None
# 4         Palm Beach        NaN         NaN       NaN         None       None
# ...              ...        ...         ...       ...          ...        ...
# 18349     Pittsburgh        NaN         NaN       NaN         None       None
# 18350  San Francisco     2005.0         3.0      25.0          USA         CA
# 18351      San Mateo        NaN         NaN       NaN         None       None
# 18352        Holland        NaN         NaN       NaN         None       None
# 18353      St. Louis     1978.0         3.0      27.0          USA         CA
#
#           deathcity namefirst  namelast        namegiven  weight  height bats  \
# 0              None     David   Aardsma      David Allan   205.0    75.0    R
# 1              None      Hank     Aaron      Henry Louis   180.0    72.0    R
# 2           Atlanta    Tommie     Aaron       Tommie Lee   190.0    75.0    R
# 3              None       Don      Aase   Donald William   190.0    75.0    R
# 4              None      Andy      Abad    Fausto Andres   184.0    73.0    L
# ...             ...       ...       ...              ...     ...     ...  ...
# 18349          None       Bob    Zupcic           Robert   220.0    76.0    R
# 18350    Burlingame     Frank      Zupo     Frank Joseph   182.0    71.0    L
# 18351          None      Paul   Zuvella             Paul   173.0    72.0    R
# 18352          None    George  Zuverink           George   195.0    76.0    R
# 18353  La Crescenta     Dutch  Zwilling  Edward Harrison   160.0    66.0    L
#
#       throws       debut   finalgame   retroid    bbrefid
# 0          R  2004-04-06  2013-09-28  aardd001  aardsda01
# 1          R  1954-04-13  1976-10-03  aaroh101  aaronha01
# 2          R  1962-04-10  1971-09-26  aarot101  aaronto01
# 3          R  1977-07-26  1990-10-03  aased001   aasedo01
# 4          L  2001-09-10  2006-04-13  abada001   abadan01
# ...      ...         ...         ...       ...        ...
# 18349      R  1991-09-07  1994-08-04  zupcb001  zupcibo01
# 18350      R  1957-07-01  1961-05-09  zupof101   zupofr01
# 18351      R  1982-09-04  1991-05-02  zuvep001  zuvelpa01
# 18352      R  1951-04-21  1959-06-15  zuveg101  zuverge01
# 18353      L  1910-08-14  1916-07-12  zwild101  zwilldu01
#
# [18354 rows x 24 columns]

# %%
query = '''
SELECT nameFirst, nameLast, DATE(finalgame) - DATE(debut) AS day_diff
FROM Master
WHERE DATE(finalgame) > DATE(debut)
ORDER BY day_diff DESC
'''

pd.read_sql_query(query, cnx)
# Out:
#       namefirst  namelast  day_diff
# 0          Nick   Altrock     12862
# 1           Jim  O'Rourke     11836
# 2        Minnie    Minoso     11492
# 3       Charley   O'Leary     11126
# 4         Arlie    Latham     10678
# ...         ...       ...       ...
# 17155      Bill      Zies         1
# 17156      John     Smith         1
# 17157        Ed  Atkinson         1
# 17158     Wally      Kopf         1
# 17159    George   Kopshaw         1
#
# [17160 rows x 3 columns]
# 2018-10-23 12:27:32,893| ERROR   | Socket exception: Connection reset by peer (54)
